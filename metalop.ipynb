# %%
# line port creating
import numpy as np
from matplotlib import pyplot as pt
x=np.arange(1,10)
y=3*x
pt.title("line ploting")
pt.xlabel("x-axis")
pt.ylabel("y-label")
pt.plot(x,y,"g-+", linewidth=2)
pt.plot(x,y*2,"r-+", linewidth=1)

pt.show()
